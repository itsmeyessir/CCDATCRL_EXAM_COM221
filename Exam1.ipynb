# %% [markdown]
# # Midterm Exam 💛💙

# %% [markdown]
# **Instructions** ❗️❗️
#
# ❌ Do not remove or modify the notebook **sections**, **subsections**, **exam questions** or **any text** in this python notebook
#
# ✔️ Put your answer in the designated cells below each question

# %% [markdown]
# ## Search

# %%
def linearSearch(my_list, number):

    index = 0

    for i in my_list:

        if my_list[index] == number:
            return index

        index = index + 1

    return -1

# %% [markdown]
# 1. Using **linear search**, write a `findLargestIncrease()` function to find the largest increase in value between two adjacent numbers in your student number `(10 points)`
#
#     **Example:**
#
#     student_number = [2,0,2,2,6,2,5,1,9,3]
#
#     **Expected Output:**
#
#     findLargestIncrease(student_number)
#
#     Output: Between 1 and 9
#
#     **Explanation:**
#
#     From this student_number, the largest increase happened from number 1 to number 9

# %%
# put your answer here
def findLargestIncrease(student_number):
    if len(student_number) < 2:
        return "No adjacent elements to compare"

    largest_increase = 0
    start_index = 0
    end_index = 0

    for i in range(len(student_number) - 1):
        current_increase = student_number[i + 1] - student_number[i]

        if current_increase > largest_increase:
            largest_increase = current_increase
            start_index = linearSearch(student_number, student_number[i])
            end_index = linearSearch(student_number, student_number[i + 1])

    if largest_increase > 0:
        return f"Between {student_number[start_index]} and {student_number[end_index]}"
    else:
        return "No increase found in adjacent numbers"

student_number = [2, 0, 2, 2, 1, 0, 3, 3, 1, 0]
result = findLargestIncrease(student_number)
print("Student Number:", student_number)
print("Output:", result)
print("Explanation: From this student number, the largest increase happened from between 0 to 3")
# Out:
# Student Number: [2, 0, 2, 2, 1, 0, 3, 3, 1, 0]
# Output: Between 0 and 3
# Explanation: From this student number, the largest increase happened from between 0 to 3

# %% [markdown]
# 2. Using **linear search**, write a `findLargestDecrease()` function to find the largest decrease in value between two adjacent numbers in your student number `(10 points)`
#
#     **Example:**
#
#     student_number = [2,0,2,2,6,2,5,1,9,3]
#
#     **Expected Output:**
#
#     findLargestDecrease(student_number)
#
#     Output: Between 9 and 3
#
#     **Explanation:**
#
#     From this student_number, the largest decrease happened from number 9 to number 3

# %%
# put your answer here
def findLargestDecrease(student_number):
    if len(student_number) < 2:
        return "No adjacent elements to compare"

    largest_decrease = 0
    start_index = 0
    end_index = 0

    for i in range(len(student_number) - 1):
        current_decrease = student_number[i] - student_number[i + 1]

        if current_decrease > largest_decrease:
            largest_decrease = current_decrease
            start_index = linearSearch(student_number, student_number[i])
            end_index = linearSearch(student_number, student_number[i + 1])

    if largest_decrease > 0:
        return f"Between {student_number[start_index]} and {student_number[end_index]}"
    else:
        return "No decrease found in adjacent numbers"

student_number = [2, 0, 2, 2, 1, 0, 3, 3, 1, 0]
result = findLargestDecrease(student_number)
print("Student Number:", student_number)
print("Output:", result)
print("Explanation: From this student number, the largest decrease happened from between 2 to 0")
# Out:
# Student Number: [2, 0, 2, 2, 1, 0, 3, 3, 1, 0]
# Output: Between 2 and 0
# Explanation: From this student number, the largest decrease happened from between 2 to 0

# %% [markdown]
# ## Linked List

# %%
class Node:

    def __init__(self, data):
        self.data = data
        self.next = None  # null

# %%
class LinkedList:

    def __init__(self):
        self.head = None

    def traverse(self, node):
        while node:
            print(node.data, end=" -> ")
            node = node.next

# %% [markdown]
# **Instructions** ❗️❗️
#
# Use the pre-defined linked list class/functions to create a linked list

# %% [markdown]
# 1. Create a Singly linked list named **num_list** and print all of its elements. `(5 points)`
#
# - **num_list** should contain all digits of your student number.
#
#     **Expected Output:**
#
#     print(num_list)
#
#     [2, 0, 2, 2, 1, 2, 3, 4, 5, 6]

# %%
# put your answer here
student_number = 2022103310
num_list = LinkedList()

digits = [int(digit) for digit in str(student_number)]

for digit in digits:
    new_node = Node(digit)
    if not num_list.head:
        num_list.head = new_node
    else:
        current_node = num_list.head
        while current_node.next:
            current_node = current_node.next
        current_node.next = new_node

num_list.traverse(num_list.head)
# Out:
# 2 -> 0 -> 2 -> 2 -> 1 -> 0 -> 3 -> 3 -> 1 -> 0 ->

# %% [markdown]
# 2. Write a `hasPrime()` function to test whether a prime number is in the last six digits of **num_list**. `(5 points)`
#
# - If a prime number is in the last six digits of **num_list**, the method should return **true**
#
# - If a prime number is not in the last six digits of **num_list**, the method should return **false**
#
#     **Expected Output:**
#
#     hasPrime(num_list)
#
#     True

# %%
# put your answer here
def is_prime(num):
    if num <= 1:
        return False
    if num <= 3:
        return True
    if num % 2 == 0 or num % 3 == 0:
        return False
    i = 5
    while i * i <= num:
        if num % i == 0 or num % (i + 2) == 0:
            return False
        i += 6
    return True

def hasPrime(num_list):
    last_six_digits = []
    current_node = num_list.head

    while current_node:
        last_six_digits.append(current_node.data)
        current_node = current_node.next
        if len(last_six_digits) > 6:
            last_six_digits.pop(0)

    for digit in last_six_digits:
        if is_prime(digit):
            return True

    return False

student_number = 2022103310
num_list = LinkedList()
digits = [int(digit) for digit in str(student_number)]
for digit in digits:
    new_node = Node(digit)
    if not num_list.head:
        num_list.head = new_node
    else:
        current_node = num_list.head
        while current_node.next:
            current_node = current_node.next
        current_node.next = new_node

result = hasPrime(num_list)
print(result)
# Out:
# True

# %% [markdown]
# 3. Write a `removeZeroes()` function to remove all occurrences of zeroes in **num_list**. `(5 points)`
#
# - If a zero is in **num_list**, return **num_list**
#
# - If there are no zeroes in **num_list**, return **"no zeros found"**
#
#     **Expected Output:**
#
#     removeZeroes(num_list)
#
#     [2, 2, 1, 2, 3, 4, 5, 6]

# %%
# put your answer here
def removeZeroes(num_list):
    current_node = num_list.head
    prev_node = None
    zero_found = False

    while current_node:
        if current_node.data == 0:
            zero_found = True
            if prev_node is None:
                num_list.head = current_node.next
            else:
                prev_node.next = current_node.next
        else:
            prev_node = current_node
        current_node = current_node.next

    if zero_found:
        return num_list
    else:
        return "no zeros found"

student_number = 2022103310
num_list = LinkedList()
digits = [int(digit) for digit in str(student_number)]
for digit in digits:
    new_node = Node(digit)
    if not num_list.head:
        num_list.head = new_node
    else:
        current_node = num_list.head
        while current_node.next:
            current_node = current_node.next
        current_node.next = new_node

result = removeZeroes(num_list)

if isinstance(result, str):
    print(result)
else:
    num_list.traverse(num_list.head)
# Out:
# 2 -> 2 -> 2 -> 1 -> 3 -> 3 -> 1 ->

# %% [markdown]
# 4. Insert a dash symbol between the 4th and 5th digit in **num_list**. `(5 points)`
#
#     **Expected Output:**
#
#     print(num_list)
#
#     [2, 0, 2, 2, "-", 1, 2, 3, 4, 5, 6]

# %%
# put your answer here
def insertDash(num_list):

    dash_node = Node("-")

    current_node = num_list.head
    prev_node = None
    count = 0

    while current_node:
        count += 1
        if count == 4:
            dash_node.next = current_node.next
            current_node.next = dash_node
            break
        prev_node = current_node
        current_node = current_node.next

student_number = 2022103310
num_list = LinkedList()
digits = [int(digit) for digit in str(student_number)]
for digit in digits:
    new_node = Node(digit)
    if not num_list.head:
        num_list.head = new_node
    else:
        current_node = num_list.head
        while current_node.next:
            current_node = current_node.next
        current_node.next = new_node

insertDash(num_list)

num_list.traverse(num_list.head)
# Out:
# 2 -> 0 -> 2 -> 2 -> - -> 1 -> 0 -> 3 -> 3 -> 1 -> 0 ->

# %% [markdown]
# ## Stack

# %%
# Creating a stack
def create_stack():
    stack = []
    return stack


def print_stack(stack):

    if (check_empty(stack)):
        return "stack is empty"

    # Create a copy of the stack and reverse the elements
    tempStack = stack.copy()
    tempStack.reverse()

    # Print all elements using a loop
    for i in tempStack:
        print(i)

    # Delete the copy to free up memory
    del tempStack

# Creating an empty stack


def check_empty(stack):
    return len(stack) == 0


# Adding items into the stack
def push(stack, item):
    stack.append(item)
    print("pushed item: " + item)


# Removing an element from the stack
def pop(stack):
    if (check_empty(stack)):
        return "stack is empty"

    return stack.pop()


def peek(stack):

    # Use negative indexing to display the last element of the list
    print(stack[-1])

# %% [markdown]
# **Instructions** ❗️❗️
#
# Use the pre-defined stack class/functions to create a stack

# %% [markdown]
# 1. Create two (2) stacks named **name_stack** and **num_stack** `(5 points)`
#
# - **name_stack** should contain all letters of your first name.
# - **num_stack** should contain all digits of your student number.
#
#     **Expected Output:**
#
#     print(name_stack)
#
#     ['E', 'L', 'I', 'Z', 'E', 'R']
#
#     print(num_stack)
#
#     [2,0,2,2,1,2,3,4,5,6]

# %%
# put your answer here
first_name = "ROBBIE"
name_stack = create_stack()
for letter in reversed(first_name):
    push(name_stack, letter)

student_number = 2022103310
num_stack = create_stack()
digits = [int(digit) for digit in reversed(str(student_number))]
for digit in digits:
    push(num_stack, str(digit))

print("\nname_stack:")
print("[", end="")
while not check_empty(name_stack):
    if len(name_stack) > 1:
        print(pop(name_stack), end=", ")
    else:
        print(pop(name_stack), end="")
print("]")

print("\nnum_stack:")
print("[", end="")
while not check_empty(num_stack):
    if len(num_stack) > 1:
        print(pop(num_stack), end=", ")
    else:
        print(pop(num_stack), end="")
print("]")
# Out:
# pushed item: E
# pushed item: I
# pushed item: B
# pushed item: B
# pushed item: O
# pushed item: R
# pushed item: 0
# pushed item: 1
# pushed item: 3
# pushed item: 3
# pushed item: 0
# pushed item: 1
# pushed item: 2
# pushed item: 2
# pushed item: 0
# pushed item: 2
#
# name_stack:
# [R, O, B, B, I, E]
#
# num_stack:
# [2, 0, 2, 2, 1, 0, 3, 3, 1, 0]

# %% [markdown]
# 2. Create a stack named **my_stack** that follows the following format: `(5 points)`
#
# - The first element should be the **5th digit in your student number**
# - The succeeding elements should be the letters of your **first name**
# - The last element should be the **last digit of your student number**
#
#     **Expected Output:**
#
#     my_stack = [1, E, L, I, Z, E, R, 6]

# %%
# put your answer here
student_number = "2022103310"
first_name = "ROBBIE"

my_stack = create_stack()

push(my_stack, student_number[4])
for letter in first_name:
    push(my_stack, letter)
push(my_stack, student_number[-1])

print("\nmy_stack =", my_stack)
# Out:
# pushed item: 1
# pushed item: R
# pushed item: O
# pushed item: B
# pushed item: B
# pushed item: I
# pushed item: E
# pushed item: 0
#
# my_stack = ['1', 'R', 'O', 'B', 'B', 'I', 'E', '0']

# %% [markdown]
# 3. Write a `verifyStack()` function that will take in `my_stack` and check if its format has been followed `(10 points)`
#
# - Return **True** if the format has been followed
# - Return **False** if the format was not followed
# - Verify the format by checking the contents of **my_stack** with **name_stack** and **num_stack**
#
#     **Expected Output:**
#
#     my_stack = [1, E, L, I, Z, E, R, 6]
#
#     verifyStack(my_stack)
#
#     True
#
#     my_stack = [1, S, L, I, Z, E, R, 7]
#
#     verifyStack(my_stack)
#
#     False

# %%
# put your answer here
def verifyStack(my_stack):
    name_stack = ['R', 'O', 'B', 'B', 'I', 'E']
    num_stack = ['1', '0']

    name_index = 0
    num_index = 0

    for item in my_stack:
        if item in name_stack and name_index < len(name_stack):

            if item == name_stack[name_index]:
                name_index += 1
            else:
                return False
        elif str(item) in num_stack and num_index < len(num_stack):

            if str(item) == num_stack[num_index]:
                num_index += 1
            else:
                return False
        else:
            return False

    return name_index == len(name_stack) and num_index == len(num_stack)

my_stack1 = [1, 'R', 'O', 'B', 'B', 'I', 'E', 0]
print(verifyStack(my_stack1))

my_stack2 = [1, 'R', 'O', 'B', 'B', 'I', 'E', 1]
print(verifyStack(my_stack2))
# Out:
# True
# False

# %% [markdown]
# ## Queue

# %%
class Queue:
    def __init__(self):
        self.queue = []

    # Add an element
    def enqueue(self, item):
        self.queue.append(item)

    # Remove an element
    def dequeue(self):
        if len(self.queue) < 1:
            return None
        return self.queue.pop(0)

    # Display  the queue
    def display(self):
        print(self.queue)

    def size(self):
        return len(self.queue)

    def peek(self):
        return self.queue[0]

# %% [markdown]
# **Instructions** ❗️❗️
#
# Use the pre-defined queue class/functions to create a Queue

# %% [markdown]
# 1. Create a simple queue named **num_queue** `(5 points)`
#
# - **num_queue** should contain all digits of your student number.
#
#     **Expected Output:**
#
#     print(num_queue)
#
#     [2,0,2,2,1,2,3,4,5,6]

# %%
# put your answer here
student_number = "2022103310"
num_queue = Queue()

for digit in student_number:
    num_queue.enqueue(int(digit))

print("print(num_queue)")
num_queue.display()
# Out:
# print(num_queue)
# [2, 0, 2, 2, 1, 0, 3, 3, 1, 0]

# %% [markdown]
# 2. Write a `getMax()` or `getMin()` function for **num_queue** `(5 points)`
#
# - If your student number ends with an odd number, create a `getMax()` function that will return the largest number in **num_queue**
# - If your student number ends with an even number, create a `getMin()` function that will return the lowest number in **num_queue**
#
#     **Expected Output for getMax():**
#
#     getMax(num_queue)
#
#     6
#
#     **Expected Output for getMin():**
#
#     getMin(num_queue)
#
#     0

# %%
# put your answer here
def getMax(queue):
    if len(queue.queue) == 0:
        return None
    max_value = max(queue.queue)
    return max_value

def getMin(queue):
    if len(queue.queue) == 0:
        return None
    min_value = min(queue.queue)
    return min_value

student_number = "2022103310"
num_queue = Queue()

for digit in student_number:
    num_queue.enqueue(int(digit))

last_digit = int(student_number[-1])

if last_digit % 2 == 0:
    result = getMin(num_queue)
    print("getMin(num_queue)\n")
else:
    result = getMax(num_queue)
    print("getMax(num_queue)\n")

print(result)
# Out:
# getMin(num_queue)
#
# 0

# %% [markdown]
# 3. Write a `getOdd()` or `getEven()` function for  **num_queue** `(5 points)`
#
# - If your student number ends with an **odd number**, create a `getOdd()` function that will return all odd numbers in **num_queue**
# - If your student number ends with an **even number**, create a `getEven()` function that will return all even numbers in **num_queue**
#
#     **Expected Output for getOdd():**
#
#     getOdd(num_queue)
#
#     [1, 3, 5]
#
#     **Expected Output for getEven():**
#
#     getEven(num_queue)
#
#     [0, 2, 4, 6]

# %%
# put your answer here
def getOdd(queue):
    odd_numbers = set()
    for item in queue.queue:
        if item % 2 != 0:
            odd_numbers.add(item)
    return list(odd_numbers)

def getEven(queue):
    even_numbers = set()
    for item in queue.queue:
        if item % 2 == 0:
            even_numbers.add(item)
    return list(even_numbers)

student_number = "2022103310"

num_queue = Queue()

for digit in student_number:
    num_queue.enqueue(int(digit))

last_digit = int(student_number[-1])

if last_digit % 2 == 0:
    result = getEven(num_queue)
    print("getEven(num_queue)\n")
else:
    result = getOdd(num_queue)
    print("getOdd(num_queue)\n")

print(result)
# Out:
# getEven(num_queue)
#
# [0, 2]

# %% [markdown]
# 4. Write a `removeDup()` function that will remove all duplicates in **num_queue** `(5 points)`
#
#     **Expected Output:**
#
#     removeDup(num_queue)
#
#     [2,0,1,3,4,5,6]

# %%
# put your answer here
def removeDup(queue):
    unique_items = set()
    new_queue = Queue()

    for item in queue.queue:
        if item not in unique_items:
            unique_items.add(item)
            new_queue.enqueue(item)

    queue.queue = new_queue.queue

student_number = "2022103310"

num_queue = Queue()

for digit in student_number:
    num_queue.enqueue(int(digit))

removeDup(num_queue)

print("removeDup(num_queue)")
num_queue.display()
# Out:
# removeDup(num_queue)
# [2, 0, 1, 3]

# %% [markdown]
# ## Sort

# %% [markdown]
# **Instructions** ❗️❗️
#
# Use the any sorting algoritms

# %% [markdown]
# 1. Using any sorting algorithm, sort the **last 6 digits** of your student number in ascending order `(5 points)`
#
#     **Example:**
#
#     student_number = [2,0,2,2,6,2,5,1,3,4]
#
#     **Expected Output:**
#
#     print(student_number)
#
#     [2,0,2,2,1,2,3,4,5,6]

# %%
# put your answer here
def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    left = arr[:mid]
    right = arr[mid:]

    left = merge_sort(left)
    right = merge_sort(right)

    return merge(left, right)

def merge(left, right):
    result = []
    i = j = 0

    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1

    result.extend(left[i:])
    result.extend(right[j:])
    return result

student_number = [2, 0, 2, 2, 1, 0, 3, 3, 1, 0]

sorted_last_six_digits = merge_sort(student_number[-6:])
student_number[-6:] = sorted_last_six_digits

print("print(student_number)")
print(student_number)
# Out:
# print(student_number)
# [2, 0, 2, 2, 0, 0, 1, 1, 3, 3]

# %% [markdown]
# 2. Using your student_number, separately sort the even numbers in **increasing order** and the odd numbers in **decreasing order** `(15 points)`
#
#     **Example:**
#
#     student_number = [2,0,2,2,1,2,3,4,5,6]
#
#     **Expected Output:**
#
#     print(student_number)
#
#     [0,2,2,2,2,4,6,5,3,1]

# %%
# put your answer here
def merge_sort(arr, reverse=False):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    left = arr[:mid]
    right = arr[mid:]

    left = merge_sort(left, reverse)
    right = merge_sort(right, reverse)

    return merge(left, right, reverse)

def merge(left, right, reverse=False):
    result = []
    i = j = 0

    while i < len(left) and j < len(right):
        if (left[i] < right[j]) ^ reverse:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1

    result.extend(left[i:])
    result.extend(right[j:])
    return result

student_number = [2, 0, 2, 2, 1, 0, 3, 3, 1, 0]

even_numbers = [x for x in student_number if x % 2 == 0]
odd_numbers = [x for x in student_number if x % 2 != 0]

even_numbers_sorted = merge_sort(even_numbers)
odd_numbers_sorted = merge_sort(odd_numbers, reverse=True)

student_number = even_numbers_sorted + odd_numbers_sorted

print(student_number)
# Out:
# [0, 0, 0, 2, 2, 2, 3, 3, 1, 1]
